# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.array([1.,2.,3.,4.,5.])
y = np.array([1.,3.,4.,3.,5.])

# %%
plt.scatter(x,y)
plt.axis([0,6,0,6])
plt.show()

# %% [markdown]
# ![97dcceaeb6a93cad73ad926eaeb3337.png](attachment:97dcceaeb6a93cad73ad926eaeb3337.png)

# %%
x_mean = np.mean(x)
y_mean = np.mean(y)

# %%
num = 0.0#分子
d = 0.0#分母
for x_i,y_i in zip(x,y):
    num += (x_i -x_mean)*(y_i-y_mean)
    d += (x_i - x_mean)**2

# %%
a = num/d
b = y_mean - a*x_mean

# %%
a
# Out:
# 0.8

# %%
b
# Out:
# 0.7999999999999998

# %%
y_hat = a*x+b

# %%
plt.scatter(x,y)
plt.plot(x,y_hat,color = 'r')
plt.axis([0,6,0,6])
plt.show()

# %%
x_predict = 6
y_predict = a * x_predict + b
y_predict
# Out:
# 5.6000000000000005

# %% [markdown]
# ### 使用自己的SimpleLinearRegression

# %%
from ML.SimpleLinearRegression import SimpleLinearRegression1

# %%
reg1 = SimpleLinearRegression1()
reg1.fit(x, y)
# Out:
# SimpleLinearRegression1()

# %%
reg1.predict(np.array([x_predict]))
# Out:
# array([5.6])

# %%
reg1.a_
# Out:
# 0.8

# %%
reg1.b_
# Out:
# 0.7999999999999998

# %%
y_hat1 = reg1.predict(x)

# %%
plt.scatter(x, y)
plt.plot(x, y_hat1, color = 'r')
plt.axis([0, 6, 0, 6])
plt.show()

# %%
from ML.SimpleLinearRegression import SimpleLinearRegression

# %%
reg2 = SimpleLinearRegression()
reg2.fit(x, y)
# Out:
# SimpleLinearRegression()

# %%
reg2.a_
# Out:
# 0.8

# %%
reg2.b_
# Out:
# 0.7999999999999998

# %% [markdown]
# ### 向量化实现的性能测试

# %%
m = 1000000
big_x = np.random.random(size = m)
big_y = big_x * 2.0 + 3.0 + np.random.normal(size = m)

# %%
# %timeit reg1.fit(big_x, big_y)
# %timeit reg2.fit(big_x, big_y)
# Out:
# 1.01 s ± 98.9 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# 15.2 ms ± 136 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
reg1.a_
# Out:
# 2.0067461751658464

# %%
reg1.b_
# Out:
# 2.9992853029855597

# %%
reg2.a_
# Out:
# 2.0067461751658136

# %%
reg2.b_
# Out:
# 2.9992853029855766
